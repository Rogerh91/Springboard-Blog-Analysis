# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
blog = pd.read_csv('subscribers (20).csv')

# %%
blog.head()
# Out:
#                         ﻿Email      Date Subscribed     IP Address  \
# 0  chinthamkarthik25@gmail.com  2016-03-23 07:51:09   183.82.201.1
# 1     tripathi.dipti@gmail.com  2016-03-24 17:34:57  208.240.15.14
# 2            ksubede@yahoo.com  2016-03-31 07:23:48   67.154.189.4
# 3        linetdmello@gmail.com  2016-04-08 03:56:57  120.61.16.174
# 4          mailme.vj@gmail.com  2016-04-11 04:08:53   192.127.94.7
#
#                                                  URL
# 0  https://www.springboard.com/blog/free-public-d...
# 1                  https://www.springboard.com/blog/
# 2                  https://www.springboard.com/blog/
# 3  https://www.springboard.com/blog/free-public-d...
# 4  https://www.springboard.com/blog/data-science-...

# %%
blog['URL'].value_counts()
# Out:
# https://www.springboard.com/blog/data-science-career-paths-different-roles-industry/                                                                                                                  329
# https://www.springboard.com/blog/free-public-data-sets-data-science-project/                                                                                                                          184
# https://www.springboard.com/blog/                                                                                                                                                                     125
# https://www.springboard.com/blog/best-blogs-on-ux-design/                                                                                                                                             104
# ...

# %%
blog.rename(columns = {'Date Subscribed':'date'}, inplace = True)
blogjuly = blog[(blog['date'] > '2016-07-01') & (blog['date'] < '2016-07-31')]
blogjuly.head()
# Out:
#                         ﻿Email                 date      IP Address  \
# 40  Ninad.salastekar@gmail.com  2016-07-03 20:39:06  50.187.120.207
# 41   florin.prihotin@gmail.com  2016-07-10 12:24:38    5.148.143.68
# 66        kevrusse@indiana.edu  2016-07-04 11:44:39    68.45.31.142
# 67    liz.thompson@live.com.au  2016-07-06 21:13:15   110.32.112.49
# 68    tutor@ebiz-developer.com  2016-07-11 11:16:43    68.48.246.64
#
#                                                   URL
# 40  https://www.springboard.com/blog/data-science-...
# 41                  https://www.springboard.com/blog/
# 66  https://www.springboard.com/blog/free-public-d...
# 67  https://www.springboard.com/blog/best-blogs-on...
# 68  https://www.springboard.com/blog/probability-b...

# %%
blogjuly['URL'].count
# Out:
# <bound method Series.count of 40      https://www.springboard.com/blog/data-science-...
# 41                      https://www.springboard.com/blog/
# 66      https://www.springboard.com/blog/free-public-d...
# 67      https://www.springboard.com/blog/best-blogs-on...
# 68      https://www.springboard.com/blog/probability-b...
# 69      https://www.springboard.com/blog/free-public-d...
# 70      https://www.springboard.com/blog/machine-learn...
# 106     https://www.springboard.com/blog/best-blogs-on...
# 107     https://www.springboard.com/blog/data-science-...
# 108     https://www.springboard.com/blog/best-blogs-on...
# 109     https://www.springboard.com/blog/probability-b...
# 110     https://www.springboard.com/blog/free-public-d...
# 111                     https://www.springboard.com/blog/
# 112                     https://www.springboard.com/blog/
# 113     https://www.springboard.com/blog/highest-data-...
# 150     https://www.springboard.com/blog/free-public-d...
# ...

# %%
len(blogjuly)
# Out:
# 279

# %%
import matplotlib.pyplot as plt

# %%
blog.URL.value_counts().plot(kind='pie')
plt.axis('equal')
plt.title('Number of emails from posts')
